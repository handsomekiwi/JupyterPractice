# %% [markdown]
# <a href="https://colab.research.google.com/github/handsomekiwi/JupyterPractice/blob/master/ML_course_HW/Y2019%20HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
array = np.array([-9,20,-6.1,23.01,-5,30,-3.3,5,-1,-10,0,10,1,15,2.3,-3,3,10,4,70,6.5,20,8,78,10,150])
B = np.reshape(array, (-1, 2))
#for i in range(len(B)):
#    print(np.split(B[i], 2, axis=1
x = np.linspace(-20,20,100)
y = x**2+2*x-2
y1 = 0
y2 = 500
plt.plot(x, y, '-m', label='y=2x+1')
plt.title('Graph of y=x**2+2*x-2')
#plt.fill(x, y, color = "y")
plt.fill_between(x,y,y1,facecolor='orange')  
plt.fill_between(x,y,y2,facecolor='yellow')  
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')

plt.grid()
for i in range(len(B)):
      C=B[i][0]**2+2*B[i][0]-2-B[i][1]
      if(C > 0):      
        plt.plot(B[i][0],B[i][1],'bo')
      elif(C < 0):
        plt.plot(B[i][0],B[i][1],'ro')
      else :
        plt.plot(B[i][0],B[i][1],'go')

# %%
import matplotlib.pyplot as plt
plt.plot(*zip(*B), marker='o', color='b', ls='')

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-20,20,100)
y = x**2+2*x-2
plt.plot(*zip(*B), marker='.', color='b', ls='')
plt.plot(x, y, '-r', label='y=2x+1')
plt.title('Graph of y=x**2+2*x-2')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
