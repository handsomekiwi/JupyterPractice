# %% [markdown]
# <a href="https://colab.research.google.com/github/handsomekiwi/JupyterPractice/blob/master/ML_course_HW/Y2019%20HW2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
html=requests.get("https://tw.appledaily.com/new/realtime")
sp = BeautifulSoup(html.text,'html.parser')
for i in sp.find_all("img"):
    print(i)
# Out:
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=8028476&amp;cv=2.0&amp;cj=1"/>
# <img src="//img.appledaily.com.tw/pay/img/nextdigital_logo.svg"/>
# <img src="//img.appledaily.com.tw/pay/img/button_hamburger.svg"/>
# <img height="100%" src="//img.appledaily.com.tw/pay/img/login_white.svg" width="100%"/>
# <img alt="《蘋果》月費120元、年費8折1152元　即起可付費" class="owl-lazy" data-src="//img.appledaily.com.tw/images/thumbnail/other/b7c95e6649a54cc51972d5145681c504.jpg" src="..." tcode="《蘋果》月費120元、年費8折1152元　即起可付費"/>
# <img alt="【直播中】大搜捕後照樣遍地開花　「為香港罪人祈禱」大遊行起步" class="owl-lazy" data-src="//img.appledaily.com.tw/images/thumbnail/other/4f1d233ede9621e0cfa2b8db2b032be7.jpg" src="..." tcode="【直播中】大搜捕後照樣遍地開花　「為香港罪人祈禱」大遊行起步"/>
# <img alt="【包龍星惡行】追賢哥女兒下場慘！　溜冰冠軍遭脫光淋糖讓蟻咬「心智退化」" class="owl-lazy" data-src="//img.appledaily.com.tw/images/thumbnail/other/01d0af36996efdfb5f3686a0e5c716a9.jpg" src="..." tcode="【包龍星惡行】追賢哥女兒下場慘！　溜冰冠軍遭脫光淋糖讓蟻咬「心智退化」"/>
# ...

# %%
for i in sp.find_all("img"):
  if(i.get("data-src")):
    print(i.get("data-src"))
# Out:
# //img.appledaily.com.tw/images/thumbnail/other/b7c95e6649a54cc51972d5145681c504.jpg
# //img.appledaily.com.tw/images/thumbnail/other/4f1d233ede9621e0cfa2b8db2b032be7.jpg
# //img.appledaily.com.tw/images/thumbnail/other/01d0af36996efdfb5f3686a0e5c716a9.jpg
# //img.appledaily.com.tw/images/thumbnail/other/c99cf802c97bedc2b3f80b78c8e1622b.jpg
# //img.appledaily.com.tw/images/thumbnail/other/c9412cc0005692ad8253dfc1ce9c9e70.jpg
# //img.appledaily.com.tw/images/thumbnail/other/ce82e95ab2135042b68d62085f743bd7.jpg
# //img.appledaily.com.tw/images/thumbnail/other/e41065c47941cc315f13f8d0158f9586.jpg
# //img.appledaily.com.tw/images/thumbnail/other/693040f6d3f5157d49af3a173538f0ea.jpg
# //img.appledaily.com.tw/images/thumbnail/other/d8adaffa9bd275e8975c6f76761a872b.jpg
# //img.appledaily.com.tw/images/thumbnail/other/75ac3e24a0d83a47a8430b4940efacbe.jpg
# //img.appledaily.com.tw/images/thumbnail/other/acecf110c4fe682bc84551cc15e23429.jpg
# ...

# %%
for i in sp.find_all("img"):
  if(i.get("data-src")):
    temp=i.get("data-src")
    filename=i.get("alt")
    with open("/content/"+filename+".jpg","wb") as f:
      f.write(urlopen("http:"+temp).read())

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
import requests
html = requests.get('https://tw.appledaily.com/')
print(html.text)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="zh-TW" class="ie6 ielt8"> <![endif]-->
# <!--[if IE 7 ]>    <html lang="zh-TW" class="ie7 ielt8"> <![endif]-->
# <!--[if IE 8 ]>    <html lang="zh-TW" class="ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--> <html lang="zh-TW"> <!--<![endif]-->
# <head>
#     <!-- BEGIN LivePerson Monitor. -->
# ...

# %%
sp = BeautifulSoup(html.text, 'html.parser')

# %%
sp.find("aside")
# Out:
# <aside>
# <ul class="mrt">
# ...

# %%
sp.find("time")
# Out:
# <time>20:26</time>

# %%
sp.find("aside").find("a").text
# Out:
# '【中職】守備還要再加強\u3000楊晉豪把壓...'

# %%
sp.find("aside").find("a")

# %%
sp.find_all("time")
# Out:
# [<time>20:26</time>,
#  <time>20:22</time>,
#  <time>20:21</time>,
#  <time>20:20</time>,
#  <time>20:14</time>,
#  <time>20:11</time>,
#  <time>20:10</time>,
#  <time>20:07</time>]

# %%
import os
os.getcwd()
# Out:
# '/content'
